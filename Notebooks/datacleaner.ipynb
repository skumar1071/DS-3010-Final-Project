# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path("Data")

listings = pd.read_csv(DATA_DIR / "listings.csv.gz")

print("Listings shape: ", listings.shape)

listings.head(5)

listings.columns

listings.info()
# Out:
# Listings shape:  (4419, 79)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4419 entries, 0 to 4418
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4419 non-null   int64
#  1   listing_url                                   4419 non-null   object
#  2   scrape_id                                     4419 non-null   int64
#  3   last_scraped                                  4419 non-null   object
#  4   source                                        4419 non-null   object
#  5   name                                          4419 non-null   object
#  6   description                                   4372 non-null   object
#  7   neighborhood_overview                         2279 non-null   object
#  8   picture_url                                   4419 non-null   object
#  9   host_id                                       4419 non-null   int64
#  10  host_url                                      4419 non-null   object
#  11  host_name                                     4418 non-null   object
#  12  host_since                                    4418 non-null   object
#  13  host_location                                 3531 non-null   object
#  14  host_about                                    2933 non-null   object
#  15  host_response_time                            3877 non-null   object
#  16  host_response_rate                            3877 non-null   object
#  17  host_acceptance_rate                          3894 non-null   object
#  18  host_is_superhost                             4190 non-null   object
#  19  host_thumbnail_url                            4418 non-null   object
#  20  host_picture_url                              4418 non-null   object
#  21  host_neighbourhood                            4314 non-null   object
#  22  host_listings_count                           4418 non-null   float64
#  23  host_total_listings_count                     4418 non-null   float64
#  24  host_verifications                            4418 non-null   object
#  25  host_has_profile_pic                          4418 non-null   object
#  26  host_identity_verified                        4418 non-null   object
#  27  neighbourhood                                 2279 non-null   object
#  28  neighbourhood_cleansed                        4419 non-null   object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      4419 non-null   float64
#  31  longitude                                     4419 non-null   float64
#  32  property_type                                 4419 non-null   object
#  33  room_type                                     4419 non-null   object
#  34  accommodates                                  4419 non-null   int64
#  35  bathrooms                                     3552 non-null   float64
#  36  bathrooms_text                                4396 non-null   object
#  37  bedrooms                                      4114 non-null   float64
#  38  beds                                          3550 non-null   float64
#  39  amenities                                     4419 non-null   object
#  40  price                                         3506 non-null   object
#  41  minimum_nights                                4419 non-null   int64
#  42  maximum_nights                                4419 non-null   int64
#  43  minimum_minimum_nights                        4417 non-null   float64
#  44  maximum_minimum_nights                        4417 non-null   float64
#  45  minimum_maximum_nights                        4417 non-null   float64
#  46  maximum_maximum_nights                        4417 non-null   float64
#  47  minimum_nights_avg_ntm                        4419 non-null   float64
#  48  maximum_nights_avg_ntm                        4419 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              4231 non-null   object
#  51  availability_30                               4419 non-null   int64
#  52  availability_60                               4419 non-null   int64
#  53  availability_90                               4419 non-null   int64
#  54  availability_365                              4419 non-null   int64
#  55  calendar_last_scraped                         4419 non-null   object
#  56  number_of_reviews                             4419 non-null   int64
#  57  number_of_reviews_ltm                         4419 non-null   int64
#  58  number_of_reviews_l30d                        4419 non-null   int64
#  59  availability_eoy                              4419 non-null   int64
#  60  number_of_reviews_ly                          4419 non-null   int64
#  61  estimated_occupancy_l365d                     4419 non-null   int64
#  62  estimated_revenue_l365d                       3506 non-null   float64
#  63  first_review                                  3448 non-null   object
#  64  last_review                                   3448 non-null   object
#  65  review_scores_rating                          3448 non-null   float64
#  66  review_scores_accuracy                        3447 non-null   float64
#  67  review_scores_cleanliness                     3448 non-null   float64
#  68  review_scores_checkin                         3446 non-null   float64
#  69  review_scores_communication                   3448 non-null   float64
#  70  review_scores_location                        3446 non-null   float64
#  71  review_scores_value                           3446 non-null   float64
#  72  license                                       2919 non-null   object
#  73  instant_bookable                              4419 non-null   object
#  74  calculated_host_listings_count                4419 non-null   int64
#  75  calculated_host_listings_count_entire_homes   4419 non-null   int64
#  76  calculated_host_listings_count_private_rooms  4419 non-null   int64
#  77  calculated_host_listings_count_shared_rooms   4419 non-null   int64
#  78  reviews_per_month                             3448 non-null   float64
# dtypes: float64(24), int64(20), object(35)
# memory usage: 2.7+ MB

# %%
# First, we remove 19 unwanted columns and store it as listings_clean

cols_to_drop = [
    "listing_url",
    "scrape_id",
    "source",
    "last_scraped",
    "name",
    "description",
    "neighborhood_overview",
    "picture_url",
    "host_url",
    "host_name",
    "host_about",
    "host_thumbnail_url",
    "host_picture_url",
    "host_verifications",
    "neighbourhood",
    "neighbourhood_group_cleansed",
    "calendar_updated",
    "calendar_last_scraped",
    "license",
]

listings_clean = listings.drop(columns=cols_to_drop)

print("Original # columns:", listings.shape[1])
print("New # columns:", listings_clean.shape[1])

listings_clean.head(5)
# Out:
# Original # columns: 79
# New # columns: 60
#       id  host_id  host_since                 host_location  \
# 0   3781     4804  2008-12-03  Massachusetts, United States
# 1   5506     8229  2009-02-19                    Boston, MA
# 2   6695     8229  2009-02-19                    Boston, MA
# 3   8789    26988  2009-07-22                    Boston, MA
# 4  10811    38997  2009-09-16                           NaN
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0        within a day               100%                  19%
# 1      within an hour               100%                 100%
# 2      within an hour               100%                 100%
# 3  within a few hours               100%                  37%
# 4  within a few hours                94%                  59%
#
#   host_is_superhost host_neighbourhood  host_listings_count  ...  \
# 0                 t        East Boston                  3.0  ...
# 1                 t            Roxbury                 12.0  ...
# 2                 t            Roxbury                 12.0  ...
# 3                 t        Beacon Hill                  8.0  ...
# 4                 f           Back Bay                 21.0  ...
#
#    review_scores_checkin review_scores_communication review_scores_location  \
# 0                   5.00                        4.96                   4.85
# 1                   4.95                        4.90                   4.58
# 2                   4.90                        4.94                   4.54
# 3                   4.93                        4.97                   4.97
# 4                   4.56                        4.00                   5.00
#
#   review_scores_value  instant_bookable  calculated_host_listings_count  \
# 0                4.88                 f                               1
# 1                4.77                 f                              11
# 2                4.72                 f                              11
# 3                4.59                 f                               4
# 4                4.67                 f                              12
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                          11
# 2                                          11
# 3                                           4
# 4                                          12
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.21
# 1                                            0               0.69
# 2                                            0               0.72
# 3                                            0               0.21
# 4                                            0               0.08
#
# [5 rows x 60 columns]

# %%
# Can verify columns got dropped

listings_clean.columns

listings_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4419 entries, 0 to 4418
# Data columns (total 60 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4419 non-null   int64
#  1   host_id                                       4419 non-null   int64
#  2   host_since                                    4418 non-null   object
#  3   host_location                                 3531 non-null   object
#  4   host_response_time                            3877 non-null   object
#  5   host_response_rate                            3877 non-null   object
#  6   host_acceptance_rate                          3894 non-null   object
#  7   host_is_superhost                             4190 non-null   object
#  8   host_neighbourhood                            4314 non-null   object
#  9   host_listings_count                           4418 non-null   float64
#  10  host_total_listings_count                     4418 non-null   float64
#  11  host_has_profile_pic                          4418 non-null   object
#  12  host_identity_verified                        4418 non-null   object
#  13  neighbourhood_cleansed                        4419 non-null   object
#  14  latitude                                      4419 non-null   float64
#  15  longitude                                     4419 non-null   float64
#  16  property_type                                 4419 non-null   object
#  17  room_type                                     4419 non-null   object
#  18  accommodates                                  4419 non-null   int64
#  19  bathrooms                                     3552 non-null   float64
#  20  bathrooms_text                                4396 non-null   object
#  21  bedrooms                                      4114 non-null   float64
#  22  beds                                          3550 non-null   float64
#  23  amenities                                     4419 non-null   object
#  24  price                                         3506 non-null   object
#  25  minimum_nights                                4419 non-null   int64
#  26  maximum_nights                                4419 non-null   int64
#  27  minimum_minimum_nights                        4417 non-null   float64
#  28  maximum_minimum_nights                        4417 non-null   float64
#  29  minimum_maximum_nights                        4417 non-null   float64
#  30  maximum_maximum_nights                        4417 non-null   float64
#  31  minimum_nights_avg_ntm                        4419 non-null   float64
#  32  maximum_nights_avg_ntm                        4419 non-null   float64
#  33  has_availability                              4231 non-null   object
#  34  availability_30                               4419 non-null   int64
#  35  availability_60                               4419 non-null   int64
#  36  availability_90                               4419 non-null   int64
#  37  availability_365                              4419 non-null   int64
#  38  number_of_reviews                             4419 non-null   int64
#  39  number_of_reviews_ltm                         4419 non-null   int64
#  40  number_of_reviews_l30d                        4419 non-null   int64
#  41  availability_eoy                              4419 non-null   int64
#  42  number_of_reviews_ly                          4419 non-null   int64
#  43  estimated_occupancy_l365d                     4419 non-null   int64
#  44  estimated_revenue_l365d                       3506 non-null   float64
#  45  first_review                                  3448 non-null   object
#  46  last_review                                   3448 non-null   object
#  47  review_scores_rating                          3448 non-null   float64
#  48  review_scores_accuracy                        3447 non-null   float64
#  49  review_scores_cleanliness                     3448 non-null   float64
#  50  review_scores_checkin                         3446 non-null   float64
#  51  review_scores_communication                   3448 non-null   float64
#  52  review_scores_location                        3446 non-null   float64
#  53  review_scores_value                           3446 non-null   float64
#  54  instant_bookable                              4419 non-null   object
#  55  calculated_host_listings_count                4419 non-null   int64
#  56  calculated_host_listings_count_entire_homes   4419 non-null   int64
#  57  calculated_host_listings_count_private_rooms  4419 non-null   int64
#  58  calculated_host_listings_count_shared_rooms   4419 non-null   int64
#  59  reviews_per_month                             3448 non-null   float64
# dtypes: float64(22), int64(19), object(19)
# memory usage: 2.0+ MB

# %%
# Drop rows with missing price
print("Before dropping missing price:", listings_clean.shape)

listings_clean = listings_clean[listings_clean["price"].notna()].copy()

print("After dropping missing price:", listings_clean.shape)

# Convert price from string like "$125.00" -> float 125.0
listings_clean["price"] = (
    listings_clean["price"]
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .astype(float)
)

listings_clean[["price"]].head()
# Out:
# Before dropping missing price: (4419, 60)
# After dropping missing price: (3506, 60)
#    price
# 0  125.0
# 1  129.0
# 2  168.0
# 3  140.0
# 4  166.0

# %%
# Now we can clean columns that have "%" in them

percent_cols = ["host_response_rate", "host_acceptance_rate"]

for col in percent_cols:
    listings_clean[col] = (
        listings_clean[col]
        .str.rstrip("%")   
        .astype(float)     
    )

listings_clean[percent_cols].head()
# Out:
#    host_response_rate  host_acceptance_rate
# 0               100.0                  19.0
# 1               100.0                 100.0
# 2               100.0                 100.0
# 3               100.0                  37.0
# 4                94.0                  59.0

# %%
# Map "t"/"f" to True/False

bool_map = {"t": True, "f": False}

bool_cols = [
    "host_is_superhost",
    "host_has_profile_pic",
    "host_identity_verified",
    "has_availability",
    "instant_bookable",
]

for col in bool_cols:
    listings_clean[col] = listings_clean[col].map(bool_map)

listings_clean[bool_cols].head()
# Out:
#   host_is_superhost host_has_profile_pic host_identity_verified  \
# 0              True                 True                  False
# 1              True                 True                   True
# 2              True                 True                   True
# 3              True                 True                   True
# 4             False                 True                   True
#
#   has_availability  instant_bookable
# 0             True             False
# 1             True             False
# 2             True             False
# 3             True             False
# 4             True             False

# %%
# Convert date columns to datetime format

date_cols = ["host_since", "first_review", "last_review"]

for col in date_cols:
    listings_clean[col] = pd.to_datetime(listings_clean[col], errors="coerce")


listings_clean[date_cols].head()
listings_clean[date_cols].dtypes
# Out:
# host_since      datetime64[ns]
# first_review    datetime64[ns]
# last_review     datetime64[ns]
# dtype: object

# %%
# Can new feature engineer 3 new attributes using datetime

today = pd.Timestamp.today()

# 1. Host tenure in years
listings_clean["host_tenure_years"] = (
    (today - listings_clean["host_since"]).dt.days / 365.25
)

# 2. Days since last review
listings_clean["days_since_last_review"] = (
    (today - listings_clean["last_review"]).dt.days
)

# 3. Listing age (since first review) in years
listings_clean["listing_age_years"] = (
    (today - listings_clean["first_review"]).dt.days / 365.25
)


listings_clean[
    ["host_since", "first_review", "last_review",
     "host_tenure_years", "days_since_last_review", "listing_age_years"]
].head()
# Out:
#   host_since first_review last_review  host_tenure_years  \
# 0 2008-12-03   2015-07-10  2024-08-09          16.996578
# 1 2009-02-19   2009-03-21  2025-07-28          16.783025
# 2 2009-02-19   2009-08-06  2025-07-29          16.783025
# 3 2009-07-22   2014-08-12  2024-05-15          16.364134
# 4 2009-09-16   2016-01-09  2019-07-22          16.210815
#
#    days_since_last_review  listing_age_years
# 0                   480.0          10.398357
# 1                   127.0          16.700890
# 2                   126.0          16.323066
# 3                   566.0          11.307324
# 4                  2325.0           9.897331

# %%
# Can drop bathrooms_text

listings_clean = listings_clean.drop(columns=["bathrooms_text"])

listings_clean.columns
# Out:
# Index(['id', 'host_id', 'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights',
#        'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
#        'number_of_reviews_l30d', 'availability_eoy', 'number_of_reviews_ly',
#        'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'host_tenure_years', 'days_since_last_review', 'listing_age_years'],
#       dtype='object')

# %%
import ast

def parse_amenities(s):
    try:
        return ast.literal_eval(s)
    except (ValueError, SyntaxError, TypeError):
        return []

# Parse once into a Series of lists (if you haven't already)
amenities_parsed = listings_clean["amenities"].apply(parse_amenities)

listings_clean["n_amenities"] = amenities_parsed.apply(len)

def has_amenity(lst, keyword):
    kw = keyword.lower()
    return any(kw in a.lower() for a in lst)

# Curated list of important amenities
amenity_flags = {
    "amenity_wifi": "Wifi",
    "amenity_kitchen": "Kitchen",
    "amenity_heating": "Heating",
    "amenity_parking": "Parking",
    "amenity_ac": "Air conditioning",
    "amenity_tv": "TV",
    "amenity_washer": "Washer",
    "amenity_dryer": "Dryer",
    "amenity_dishwasher": "Dishwasher",
    "amenity_free_street_parking": "Free street parking",
    "amenity_private_entrance": "Private entrance",
    "amenity_dedicated_workspace": "Dedicated workspace",
    "amenity_self_checkin": "Self check-in",
    "amenity_pets_allowed": "Pets allowed",
    "amenity_bathtub": "Bathtub",
}

for col_name, keyword in amenity_flags.items():
    listings_clean[col_name] = amenities_parsed.apply(
        lambda lst, kw=keyword: has_amenity(lst, kw)
    )

# Quick check
listings_clean[
    ["n_amenities"]
    + list(amenity_flags.keys())
].head()
# Out:
#    n_amenities  amenity_wifi  amenity_kitchen  amenity_heating  \
# 0           28          True             True             True
# 1           29          True            False             True
# 2           29          True             True             True
# 3           33          True             True             True
# 4           22          True             True             True
#
#    amenity_parking  amenity_ac  amenity_tv  amenity_washer  amenity_dryer  \
# 0             True        True        True            True           True
# 1             True        True        True            True           True
# 2             True        True        True            True           True
# 3             True        True        True            True           True
# 4            False        True        True           False           True
#
#    amenity_dishwasher  amenity_free_street_parking  amenity_private_entrance  \
# 0                True                         True                     False
# 1               False                         True                      True
# 2                True                         True                     False
# 3               False                        False                     False
# 4               False                        False                     False
#
#    amenity_dedicated_workspace  amenity_self_checkin  amenity_pets_allowed  \
# 0                        False                 False                 False
# 1                        False                  True                 False
# 2                        False                  True                 False
# 3                        False                 False                 False
# 4                        False                 False                  True
#
#    amenity_bathtub
# 0            False
# 1             True
# 2            False
# 3             True
# 4            False

# %%
listings_clean.describe
# Out:
# <bound method NDFrame.describe of                        id    host_id host_since                 host_location  \
# 0                    3781       4804 2008-12-03  Massachusetts, United States
# 1                    5506       8229 2009-02-19                    Boston, MA
# 2                    6695       8229 2009-02-19                    Boston, MA
# 3                    8789      26988 2009-07-22                    Boston, MA
# 4                   10811      38997 2009-09-16                           NaN
# ...                   ...        ...        ...                           ...
# 4414  1514629096140818505   92524206 2016-08-29                   Everett, MA
# 4415  1514714940012290884  578741487 2024-05-20                    Boston, MA
# 4416  1514744484553712874     757253 2011-06-29                    Boston, MA
# 4417  1515306685708974789   92524206 2016-08-29                   Everett, MA
# 4418  1515466025834395498  104683790 2016-11-21                    Boston, MA
#
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 0           within a day               100.0                  19.0
# 1         within an hour               100.0                 100.0
# 2         within an hour               100.0                 100.0
# 3     within a few hours               100.0                  37.0
# 4     within a few hours                94.0                  59.0
# ...                  ...                 ...                   ...
# 4414      within an hour               100.0                 100.0
# 4415      within an hour               100.0                  94.0
# 4416      within an hour               100.0                  99.0
# 4417      within an hour               100.0                 100.0
# 4418      within an hour               100.0                 100.0
#
#      host_is_superhost host_neighbourhood  host_listings_count  ...  \
# 0                 True        East Boston                  3.0  ...
# 1                 True            Roxbury                 12.0  ...
# 2                 True            Roxbury                 12.0  ...
# 3                 True        Beacon Hill                  8.0  ...
# 4                False           Back Bay                 21.0  ...
# ...                ...                ...                  ...  ...
# 4414               NaN             Malden                 20.0  ...
# 4415              True      Lower Allston                 11.0  ...
# 4416              True           Downtown                 11.0  ...
# 4417               NaN             Malden                 20.0  ...
# 4418             False        East Boston                  3.0  ...
#
#       amenity_tv amenity_washer amenity_dryer amenity_dishwasher  \
# 0           True           True          True               True
# 1           True           True          True              False
# 2           True           True          True               True
# 3           True           True          True              False
# 4           True          False          True              False
# ...          ...            ...           ...                ...
# 4414        True           True          True               True
# 4415        True           True          True               True
# 4416        True           True          True               True
# 4417        True           True          True               True
# 4418        True           True          True              False
#
#       amenity_free_street_parking  amenity_private_entrance  \
# 0                            True                     False
# 1                            True                      True
# 2                            True                     False
# 3                           False                     False
# 4                           False                     False
# ...                           ...                       ...
# 4414                        False                     False
# 4415                         True                     False
# 4416                        False                     False
# 4417                        False                     False
# 4418                        False                      True
#
#      amenity_dedicated_workspace amenity_self_checkin  amenity_pets_allowed  \
# 0                          False                False                 False
# 1                          False                 True                 False
# 2                          False                 True                 False
# 3                          False                False                 False
# 4                          False                False                  True
# ...                          ...                  ...                   ...
# 4414                        True                 True                 False
# 4415                        True                False                 False
# 4416                        True                 True                 False
# 4417                        True                 True                 False
# 4418                       False                False                 False
#
#       amenity_bathtub
# 0               False
# 1                True
# 2               False
# 3                True
# 4               False
# ...               ...
# 4414            False
# 4415             True
# 4416             True
# 4417            False
# 4418            False
#
# [3506 rows x 78 columns]>

# %%
# Save to the Data folder
#output_path = DATA_DIR / "listings_clean.csv"
#listings_clean.to_csv(output_path, index=False)

#output_path

# %%
import sys
# !{sys.executable} -m pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/skumar010/anaconda3/envs/newsapi38/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
price_cap = listings_clean["price"].quantile(0.99)
price_cap


filtered = listings_clean[listings_clean["price"] <= price_cap].copy()
print("Original rows:", listings_clean.shape[0])
print("Filtered rows:", filtered.shape[0])
print("Price cap (99th percentile):", price_cap)
# Out:
# Original rows: 3506
# Filtered rows: 3484
# Price cap (99th percentile): 40000.0

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=filtered, x="room_type", y="price")
plt.title("Price by Room Type (Prices ≤ 99th Percentile)")
plt.xlabel("Room Type")
plt.ylabel("Price ($/night)")
plt.xticks(rotation=20)
plt.show()
